# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/Flipkart_products1.csv")

# %%
df.head()
# Out:
#   Category                                       Product Name     Price  \
# 0  Laptops                                                NaN   67,990.
# 1  Laptops                                            Results       NaN
# 2  Laptops  Lenovo Yoga Slim 7 Aura Edition Intel Evo Core...  1,47,990
# 3  Laptops  Lenovo ThinkBook 14 Intel 13th Gen Core i3 14"...    43,990
# 4  Laptops  (Refurbished) Lenovo ThinkPad 8th Gen Intel Co...    18,499
#
#                Rating Number of Reviews  Discounts  \
# 0                 NaN               NaN        NaN
# 1                 NaN               NaN        NaN
# 2  5.0 out of 5 stars                 3  (29% off)
# 3  4.1 out of 5 stars                15  (42% off)
# 4  3.4 out of 5 stars               173  (63% off)
#
#                                                 Link
# 0                                                NaN
# 1                                                NaN
# 2                 https://www.amazon.in/s?k=laptops#
# ...

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of         Category                                       Product Name     Price  \
# 0        Laptops                                                NaN   67,990.
# 1        Laptops                                            Results       NaN
# 2        Laptops  Lenovo Yoga Slim 7 Aura Edition Intel Evo Core...  1,47,990
# 3        Laptops  Lenovo ThinkBook 14 Intel 13th Gen Core i3 14"...    43,990
# 4        Laptops  (Refurbished) Lenovo ThinkPad 8th Gen Intel Co...    18,499
# ...          ...                                                ...       ...
# 1910  Headphones  WEHEAR OX Wireless Open Ear Experience Bone Co...     9,999
# 1911  Headphones                                   Related searches       NaN
# 1912  Headphones                                                NaN       NaN
# 1913  Headphones                                         Need help?       NaN
# 1914  Headphones                                                NaN       NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1915 entries, 0 to 1914
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Category           1915 non-null   object
#  1   Product Name       1620 non-null   object
#  2   Price              1447 non-null   object
#  3   Rating             1322 non-null   object
#  4   Number of Reviews  1317 non-null   object
#  5   Discounts          1350 non-null   object
#  6   Link               1436 non-null   object
# dtypes: object(7)
# memory usage: 104.9+ KB

# %%
df.drop(columns=['Link'], inplace=True)

# %%
df.to_csv('modified_file.csv', index=False)

print("Column 'link' has been dropped.")
# Out:
# Column 'link' has been dropped.

# %%
df.head()
# Out:
#   Category                                       Product Name     Price  \
# 0  Laptops                                                NaN   67,990.
# 1  Laptops                                            Results       NaN
# 2  Laptops  Lenovo Yoga Slim 7 Aura Edition Intel Evo Core...  1,47,990
# 3  Laptops  Lenovo ThinkBook 14 Intel 13th Gen Core i3 14"...    43,990
# 4  Laptops  (Refurbished) Lenovo ThinkPad 8th Gen Intel Co...    18,499
#
#                Rating Number of Reviews  Discounts
# 0                 NaN               NaN        NaN
# 1                 NaN               NaN        NaN
# 2  5.0 out of 5 stars                 3  (29% off)
# 3  4.1 out of 5 stars                15  (42% off)
# 4  3.4 out of 5 stars               173  (63% off)

# %%
df1 = pd.read_csv("/content/modified_file.csv")

# %%
df.head()
# Out:
#   Category                                       Product Name     Price  \
# 0  Laptops                                                NaN   67,990.
# 1  Laptops                                            Results       NaN
# 2  Laptops  Lenovo Yoga Slim 7 Aura Edition Intel Evo Core...  1,47,990
# 3  Laptops  Lenovo ThinkBook 14 Intel 13th Gen Core i3 14"...    43,990
# 4  Laptops  (Refurbished) Lenovo ThinkPad 8th Gen Intel Co...    18,499
#
#                Rating Number of Reviews  Discounts
# 0                 NaN               NaN        NaN
# 1                 NaN               NaN        NaN
# 2  5.0 out of 5 stars                 3  (29% off)
# 3  4.1 out of 5 stars                15  (42% off)
# 4  3.4 out of 5 stars               173  (63% off)

# %%
df1.dropna(inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1281 entries, 2 to 1909
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Category           1281 non-null   object
#  1   Product Name       1281 non-null   object
#  2   Price              1281 non-null   object
#  3   Rating             1281 non-null   object
#  4   Number of Reviews  1281 non-null   object
#  5   Discounts          1281 non-null   object
# dtypes: object(6)
# memory usage: 70.1+ KB

# %%
df1
# Out:
#         Category                                       Product Name     Price  \
# 2        Laptops  Lenovo Yoga Slim 7 Aura Edition Intel Evo Core...  1,47,990
# 3        Laptops  Lenovo ThinkBook 14 Intel 13th Gen Core i3 14"...    43,990
# 4        Laptops  (Refurbished) Lenovo ThinkPad 8th Gen Intel Co...    18,499
# 5        Laptops  Lenovo V14 G3 Intel Core i5 12th Gen 1235U /16...    37,350
# 6        Laptops  HP Laptop 255 G9 AMD Ryzen 3 3250U Dual Core -...    24,995
# ...          ...                                                ...       ...
# 1903  Headphones  Portronics Muffs M2 Bluetooth Headphones Over ...       953
# 1904  Headphones  Noise Newly Launched Airwave Max 5 Wireless Ov...     4,699
# 1905  Headphones  Noise Two Wireless On-Ear Headphones with 50 H...     1,699
# 1908  Headphones  Wecool Moonwalk M2 Bone Conduction Headphones,...     3,099
# 1909  Headphones  HAMMER Bash Over The Ear Wireless Bluetooth He...     2,099
#
# ...

# %%
df1.to_csv('modified_famazon.csv', index=False)

print("Column 'link' has been dropped.")
# Out:
# Column 'link' has been dropped.

# %%
pip install mysql-connector-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.0/34.0 MB 32.9 MB/s eta 0:00:00
# ...
